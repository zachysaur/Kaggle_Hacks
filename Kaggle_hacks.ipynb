# %% [markdown]
# # Make a Folder Inside Notebook

# %%
import os

directory_name = "pictures"  # Specify the name of the new directory you want to create
directory_path = "/kaggle/working/pictures" + directory_name  # Construct the full path of the new directory

# Create the directory
os.makedirs(directory_path)

# %% [markdown]
# # Delete Folder Inside Notebok

# %%
import shutil

directory_path = "/kaggle/working/picturespictures"  # Specify the path of the directory you want to delete

# Delete the directory
shutil.rmtree(directory_path)

# %% [markdown]
# # Move File from one Folder to other

# %%
import shutil

src_path = r"/kaggle/input/experimental/result_video.mp4"
dst_path = r"/kaggle/working/"

shutil.copy(src_path, dst_path)
# Out:
# '/kaggle/working/result_video.mp4'
